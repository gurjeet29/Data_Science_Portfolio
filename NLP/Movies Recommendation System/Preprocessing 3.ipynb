# %% [markdown]
# Extracting features of 2020 movies from Wikipedia

# %%
#importing modules
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
def dataset(link):
  source = urllib.request.urlopen(link).read()
  soup = bs.BeautifulSoup(source,'lxml')

  tables = soup.find_all('table',class_='wikitable sortable')

  df_1 = pd.read_html(str(tables[0]))[0]
  df_2 = pd.read_html(str(tables[1]))[0]
  df_3 = pd.read_html(str(tables[2]))[0]
  df_4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'
  df = df_1.append(df_2.append(df_3.append(df_4,ignore_index=True),ignore_index=True),ignore_index=True)
  
  final_df_2020 = df[['Title','Cast and crew']]
  return final_df_2020

# %%
link1 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"
final_df_2020 = dataset(link1)
final_df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 269       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 270      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 271  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 272  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 273      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [274 rows x 2 columns]

# %%
from tmdbv3api import TMDb, Movie
import json
import requests

tmdb = TMDb()
tmdb_movie = Movie()
tmdb.api_key = '22eb0026986397f50a2bbd92a1c791b9'

# %%
#getting genres from tmbd api
def get_genre(x):
  genres = []
  result = tmdb_movie.search(x)
  if not result:
    return np.NaN
  else:
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return (" ".join(genres))
    else:
        return np.NaN
final_df_2020['genres'] = final_df_2020['Title'].map(lambda x: get_genre(str(x)))    
df_2020 = final_df_2020[['Title','Cast and crew','genres']]
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 269       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 270      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 271  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 272  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 273      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres
# 0                   Horror Mystery Thriller
# 1    Action Horror Science Fiction Thriller
# 2                                    Comedy
# 3                                     Drama
# 4                      Crime Thriller Drama
# ..                                      ...
# 269            Action Fantasy Family Comedy
# 270          Drama Western Adventure Action
# 271                                   Drama
# 272                    Thriller Crime Drama
# 273                                   Drama
#
# [274 rows x 3 columns]

# %%
#getting director
def get_director(x):
      if " (director)" in x:
          return x.split(" (director)")[0]
      elif " (directors)" in x:
          return x.split(" (directors)")[0]
      else:
          return x.split(" (director/screenplay)")[0]
          
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(x))

# %%
#getting actor 1
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])
    
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(x))

#getting actor 2
def get_actor2(x):
  if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
    return np.NaN
  else:
    return ((x.split("screenplay); ")[-1]).split(", ")[1])
      
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(x))

#getting actor 3
def get_actor3(x):
  if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
    return np.NaN
  else:
    return ((x.split("screenplay); ")[-1]).split(", ")[2])
      
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(x))

# %%
#considering only the important features
df_2020 = df_2020.rename(columns={'Title':'movie_title'})
df_2020 = df_2020[['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_2020.isnull().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      5
# actor_3_name     28
# genres            3
# movie_title       0
# dtype: int64

# %%
#dropping null values
df_2020 = df_2020.dropna(how='any')

# %%
df_2020['movie_title'] = df_2020['movie_title'].str.lower()
df_2020['comb'] = df_2020['actor_1_name'] + ' ' + df_2020['actor_2_name'] + ' '+ df_2020['actor_3_name'] + ' '+ df_2020['director_name'] +' ' + df_2020['genres']
df_2020
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 268       Pete Docter             Jamie Foxx           Tina Fey
# 269  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 271       Regina King      Kingsley Ben-Adir          Eli Goree
# 272   Emerald Fennell         Carey Mulligan         Bo Burnham
# 273  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# 2        Salma Hayek                                  Comedy
# 3     Walton Goggins                                   Drama
# 4     Chandler Riggs                    Crime Thriller Drama
# ..               ...                                     ...
# 268    Graham Norton   Animation Family Comedy Fantasy Drama
# 269    YaYa Gosselin            Action Fantasy Family Comedy
# 271      Aldis Hodge                                   Drama
# 272      Alison Brie                    Thriller Crime Drama
# 273     Molly Parker                                   Drama
#
#                movie_title                                               comb
# 0               the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1               underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2              like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3            three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4        inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                     ...                                                ...
# 268                   soul  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 269       we can be heroes  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 271  one night in miami...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 272  promising young woman  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 273      pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [244 rows x 7 columns]

# %% [markdown]
# Extracting features of 2021 movies from Wikipedia

# %%
link2 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"
final_df_2021 = dataset(link2)
final_df_2021
# Out:
#                       Title                                      Cast and crew
# 0       Shadow in the Cloud  Roseanne Liang (director/screenplay); Max Land...
# 1           The White Tiger  Ramin Bahrani (director/screenplay); Adarsh Go...
# 2               Locked Down  Doug Liman (director); Steven Knight (screenpl...
# 3                   The Dig  Simon Stone (director); Moira Buffini (screenp...
# 4          Outside the Wire  Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                      ...                                                ...
# 353  The Tragedy of Macbeth  Joel Coen (director/screenplay); Denzel Washin...
# 354    A Journal for Jordan  Denzel Washington (director); Virgil Williams ...
# 355       American Underdog  Erwin brothers (directors); Jon Erwin, David A...
# 356                 Memoria  Apichatpong Weerasethakul (director/acreenplay...
# 357                     NaN                                                NaN
#
# [358 rows x 2 columns]

# %%
#getting genres from tmbd api
def get_genre(x):
  genres = []
  result = tmdb_movie.search(x)
  if not result:
    return np.NaN
  else:
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return (" ".join(genres))
    else:
        return np.NaN
final_df_2021['genres'] = final_df_2021['Title'].map(lambda x: get_genre(str(x)))    
df_2021 = final_df_2021[['Title','Cast and crew','genres']]
df_2021
# Out:
#                       Title  \
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 353  The Tragedy of Macbeth
# 354    A Journal for Jordan
# 355       American Underdog
# 356                 Memoria
# 357                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 353  Joel Coen (director/screenplay); Denzel Washin...
# 354  Denzel Washington (director); Virgil Williams ...
# 355  Erwin brothers (directors); Jon Erwin, David A...
# 356  Apichatpong Weerasethakul (director/acreenplay...
# 357                                                NaN
#
#                               genres
# 0                  Horror Action War
# 1                              Drama
# 2                 Comedy Crime Drama
# 3                      Drama History
# 4    Thriller Action Science Fiction
# ..                               ...
# 353                        Drama War
# 354                    Drama Romance
# 355                            Drama
# 356    Drama Science Fiction Mystery
# 357                           Comedy
#
# [358 rows x 3 columns]

# %%
df_2021.dropna(inplace=True)

# %%
#getting director
def get_director(x):
      if " (director)" in x:
          return x.split(" (director)")[0]
      elif " (directors)" in x:
          return x.split(" (directors)")[0]
      else:
          return x.split(" (director/screenplay)")[0]
          
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(x))

# %%
#getting actor 1
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])
    
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(x))

#getting actor 2
def get_actor2(x):
  if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
    return np.NaN
  else:
    return ((x.split("screenplay); ")[-1]).split(", ")[1])
      
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(x))

#getting actor 3
def get_actor3(x):
  if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
    return np.NaN
  else:
    return ((x.split("screenplay); ")[-1]).split(", ")[2])
      
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(x))

# %%
#considering only the important features
df_2021 = df_2021.rename(columns={'Title':'movie_title'})
df_2021 = df_2021[['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_2021.isnull().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      7
# actor_3_name     24
# genres            0
# movie_title       0
# dtype: int64

# %%
df_2021=df_2021.dropna(how='any')

# %%
df_2021['movie_title'] = df_2021['movie_title'].str.lower()
df_2021['comb'] = df_2021['actor_1_name'] + ' ' + df_2021['actor_2_name'] + ' '+ df_2021['actor_3_name'] + ' '+ df_2021['director_name'] +' ' + df_2021['genres']
df_2021
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 352                                     Matthew Vaughn
# 353                                          Joel Coen
# 354                                  Denzel Washington
# 355                                     Erwin brothers
# 356  Apichatpong Weerasethakul (director/acreenplay...
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# 3                                       Carey Mulligan      Ralph Fiennes
# 4                                       Anthony Mackie       Damson Idris
# ..                                                 ...                ...
# 352                                      Ralph Fiennes     Gemma Arterton
# 353                                  Denzel Washington  Frances McDormand
# 354                                  Michael B. Jordan       Chanté Adams
# 355                                       Zachary Levi        Anna Paquin
# 356  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#               actor_3_name                                 genres  \
# 0             Beulah Koale                      Horror Action War
# 1    Priyanka Chopra Jonas                                  Drama
# 2         Stephen Merchant                     Comedy Crime Drama
# 3               Lily James                          Drama History
# 4            Emily Beecham        Thriller Action Science Fiction
# ..                     ...                                    ...
# 352             Rhys Ifans  Action Adventure Thriller War Mystery
# 353          Bertie Carvel                              Drama War
# 354        Jalon Christian                          Drama Romance
# 355           Dennis Quaid                                  Drama
# 356         Jeanne Balibar          Drama Science Fiction Mystery
#
#                 movie_title                                               comb
# 0       shadow in the cloud  Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1           the white tiger  Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 2               locked down  Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# 3                   the dig  Carey Mulligan Ralph Fiennes Lily James Simon ...
# 4          outside the wire  Anthony Mackie Damson Idris Emily Beecham Mika...
# ..                      ...                                                ...
# 352          the king's man  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 353  the tragedy of macbeth  Denzel Washington Frances McDormand Bertie Car...
# 354    a journal for jordan  Michael B. Jordan Chanté Adams Jalon Christian...
# 355       american underdog  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 356                 memoria  Apichatpong Weerasethakul (director/acreenplay...
#
# [333 rows x 7 columns]

# %% [markdown]
# Extracting features of 2022 movies from Wikipedia

# %%
link3 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"
final_df_2022 = dataset(link3)
final_df_2022
# Out:
#                                  Title  \
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 229       Puss in Boots: The Last Wish
# 230        I Wanna Dance with Somebody
# 231                            Babylon
# 232                                NaN
# 233                                NaN
#
#                                          Cast and crew
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 229  Joel Crawford (director); Antonio Banderas, Sa...
# 230  Kasi Lemmons (director); Anthony McCarten (scr...
# 231  Damien Chazelle (director/screenplay); Brad Pi...
# 232                                                NaN
# 233                                                NaN
#
# [234 rows x 2 columns]

# %%
final_df_2022.isnull().sum()
# Out:
# Title            2
# Cast and crew    2
# dtype: int64

# %%
final_df_2022.dropna(inplace=True)

# %%
#getting genres from tmbd api
def get_genre(x):
  genres = []
  result = tmdb_movie.search(x)
  if not result:
    return np.NaN
  else:
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return (" ".join(genres))
    else:
        return np.NaN
final_df_2022['genres'] = final_df_2022['Title'].map(lambda x: get_genre(str(x)))    
df_2022 = final_df_2022[['Title','Cast and crew','genres']]
df_2022
# Out:
#                                  Title  \
# 0                              The 355
# 1             The Legend of La Llorona
# 2                         The Commando
# 3                               Scream
# 4    Hotel Transylvania: Transformania
# ..                                 ...
# 227                            Matilda
# 228           Shazam! Fury of the Gods
# 229       Puss in Boots: The Last Wish
# 230        I Wanna Dance with Somebody
# 231                            Babylon
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Matt Bettinelli-Olpin, Tyler Gillett (director...
# 4    Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 227  Matthew Warchus (director); Dennis Kelly (scre...
# 228  David F. Sandberg (director); Henry Gayden, Ch...
# 229  Joel Crawford (director); Antonio Banderas, Sa...
# 230  Kasi Lemmons (director); Anthony McCarten (scr...
# 231  Damien Chazelle (director/screenplay); Brad Pi...
#
#                                         genres
# 0                              Action Thriller
# 1                              Horror Thriller
# 2                        Action Crime Thriller
# 3                      Horror Mystery Thriller
# 4    Animation Family Fantasy Comedy Adventure
# ..                                         ...
# 227                      Comedy Family Fantasy
# 228                      Comedy Action Fantasy
# 229  Animation Adventure Comedy Family Fantasy
# 230                              Drama History
# 231  Action Adventure Science Fiction Thriller
#
# [232 rows x 3 columns]

# %%
#getting director
def get_director(x):
      if " (director)" in x:
          return x.split(" (director)")[0]
      elif " (directors)" in x:
          return x.split(" (directors)")[0]
      else:
          return x.split(" (director/screenplay)")[0]
          
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(x))

# %%
#getting actor 1
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])
    
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(x))

#getting actor 2
def get_actor2(x):
  if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
    return np.NaN
  else:
    return ((x.split("screenplay); ")[-1]).split(", ")[1])
      
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(x))

#getting actor 3
def get_actor3(x):
  if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
    return np.NaN
  else:
    return ((x.split("screenplay); ")[-1]).split(", ")[2])
      
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(x))

# %%
#considering only the important features
df_2022 = df_2022.rename(columns={'Title':'movie_title'})
df_2022 = df_2022[['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_2022=df_2022.dropna(how='any')

# %%
df_2022['movie_title'] = df_2022['movie_title'].str.lower()
df_2022['comb'] = df_2022['actor_1_name'] + ' ' + df_2022['actor_2_name'] + ' '+ df_2022['actor_3_name'] + ' '+ df_2022['director_name'] +' ' + df_2022['genres']
df_2022
# Out:
#                             director_name  \
# 0                           Simon Kinberg
# 1                  Patricia Harris Seeley
# 3    Matt Bettinelli-Olpin, Tyler Gillett
# 4           Jennifer Kluska, Derek Drymon
# 5                             Luis Prieto
# ..                                    ...
# 227                       Matthew Warchus
# 228                     David F. Sandberg
# 229                         Joel Crawford
# 230                          Kasi Lemmons
# 231                       Damien Chazelle
#
#                                    actor_1_name       actor_2_name  \
# 0                              Jessica Chastain     Lupita Nyong'o
# 1                                 Autumn Reeser       Antonio Cupo
# 3                               Melissa Barrera      Mason Gooding
# 4                                  Andy Samberg       Selena Gomez
# 5                              Cameron Monaghan       Frank Grillo
# ..                                          ...                ...
# 227                                 Alisha Weir      Lashana Lynch
# 228                                Zachary Levi  Jack Dylan Grazer
# 229  Joel Crawford (director); Antonio Banderas        Salma Hayek
# 230                                 Naomi Ackie     Ashton Sanders
# 231                                   Brad Pitt      Margot Robbie
#
#            actor_3_name                                     genres  \
# 0         Penélope Cruz                            Action Thriller
# 1           Danny Trejo                            Horror Thriller
# 3          Jenna Ortega                    Horror Mystery Thriller
# 4          Kathryn Hahn  Animation Family Fantasy Comedy Adventure
# 5            Lilly Krug                                   Thriller
# ..                  ...                                        ...
# 227  Andrea Riseborough                      Comedy Family Fantasy
# 228       Rachel Zegler                      Comedy Action Fantasy
# 229      Harvey Guillén  Animation Adventure Comedy Family Fantasy
# 230       Stanley Tucci                              Drama History
# 231       Tobey Maguire  Action Adventure Science Fiction Thriller
#
#                            movie_title  \
# 0                              the 355
# 1             the legend of la llorona
# 3                               scream
# 4    hotel transylvania: transformania
# 5                            shattered
# ..                                 ...
# 227                            matilda
# 228           shazam! fury of the gods
# 229       puss in boots: the last wish
# 230        i wanna dance with somebody
# 231                            babylon
#
#                                                   comb
# 0    Jessica Chastain Lupita Nyong'o Penélope Cruz ...
# 1    Autumn Reeser Antonio Cupo Danny Trejo Patrici...
# 3    Melissa Barrera Mason Gooding Jenna Ortega Mat...
# 4    Andy Samberg Selena Gomez Kathryn Hahn Jennife...
# 5    Cameron Monaghan Frank Grillo Lilly Krug Luis ...
# ..                                                 ...
# 227  Alisha Weir Lashana Lynch Andrea Riseborough M...
# 228  Zachary Levi Jack Dylan Grazer Rachel Zegler D...
# 229  Joel Crawford (director); Antonio Banderas Sal...
# 230  Naomi Ackie Ashton Sanders Stanley Tucci Kasi ...
# 231  Brad Pitt Margot Robbie Tobey Maguire Damien C...
#
# [216 rows x 7 columns]

# %%
df_20_21=df_2020.append(df_2021,ignore_index=True)

df_20_21_22=df_20_21.append(df_2022,ignore_index=True)

# %%
old_df = pd.read_csv('/content/data_16_17_18_19.csv')

# %%
cleaned_df = old_df.append(df_20_21_22,ignore_index=True)
cleaned_df
# Out:
#           director_name                                actor_1_name  \
# 0         James Cameron                                 CCH Pounder
# 1        Gore Verbinski                                 Johnny Depp
# 2            Sam Mendes                             Christoph Waltz
# 3     Christopher Nolan                                   Tom Hardy
# 4           Doug Walker                                 Doug Walker
# ...                 ...                                         ...
# 6666    Matthew Warchus                                 Alisha Weir
# 6667  David F. Sandberg                                Zachary Levi
# 6668      Joel Crawford  Joel Crawford (director); Antonio Banderas
# 6669       Kasi Lemmons                                 Naomi Ackie
# 6670    Damien Chazelle                                   Brad Pitt
#
#            actor_2_name          actor_3_name  \
# 0      Joel David Moore             Wes Studi
# 1         Orlando Bloom        Jack Davenport
# 2          Rory Kinnear      Stephanie Sigman
# 3        Christian Bale  Joseph Gordon-Levitt
# 4            Rob Walker               unknown
# ...                 ...                   ...
# 6666      Lashana Lynch    Andrea Riseborough
# 6667  Jack Dylan Grazer         Rachel Zegler
# 6668        Salma Hayek        Harvey Guillén
# 6669     Ashton Sanders         Stanley Tucci
# 6670      Margot Robbie         Tobey Maguire
#
#                                          genres  \
# 0               Action Adventure Fantasy Sci-Fi
# 1                      Action Adventure Fantasy
# 2                     Action Adventure Thriller
# 3                               Action Thriller
# 4                                   Documentary
# ...                                         ...
# 6666                      Comedy Family Fantasy
# 6667                      Comedy Action Fantasy
# 6668  Animation Adventure Comedy Family Fantasy
# 6669                              Drama History
# 6670  Action Adventure Science Fiction Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6666                                            matilda
# 6667                           shazam! fury of the gods
# 6668                       puss in boots: the last wish
# 6669                        i wanna dance with somebody
# 6670                                            babylon
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6666  Alisha Weir Lashana Lynch Andrea Riseborough M...
# 6667  Zachary Levi Jack Dylan Grazer Rachel Zegler D...
# 6668  Joel Crawford (director); Antonio Banderas Sal...
# 6669  Naomi Ackie Ashton Sanders Stanley Tucci Kasi ...
# 6670  Brad Pitt Margot Robbie Tobey Maguire Damien C...
#
# [6671 rows x 7 columns]

# %%
cleaned_df.to_csv('main_data.csv',index=False)
